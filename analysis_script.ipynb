# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\Lenovo\\Downloads\\Data Analyst Intern Assignment.xlsx")

# %%
df
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
user_details = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\Data Analyst Intern Assignment.xlsx", sheet_name='UserDetails.csv')

# %%
user_details
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
cooking_sessions = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\Data Analyst Intern Assignment.xlsx", sheet_name='CookingSessions.csv')

# %%
cooking_sessions
# Out:
#    Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
# 5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
# 6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
# 7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
# 8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
# 9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
# 10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
# 11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
# ...

# %%
order_details = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\Data Analyst Intern Assignment.xlsx", sheet_name='OrderDetails.csv')

# %%
order_details
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# ...

# %%
user_details_1 = user_details.drop_duplicates()

# %%
user_details_1
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
cooking_sessions_1 = cooking_sessions.drop_duplicates()

# %%
cooking_sessions_1
# Out:
#    Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0        S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1        S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2        S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3        S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4        S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
# 5        S006    U002        Spaghetti     Dinner 2024-12-03 18:30:00
# 6        S007    U005  Grilled Chicken     Dinner 2024-12-04 18:00:00
# 7        S008    U003    Veggie Burger      Lunch 2024-12-04 13:30:00
# 8        S009    U001  Grilled Chicken     Dinner 2024-12-05 19:00:00
# 9        S010    U002          Oatmeal  Breakfast 2024-12-05 07:00:00
# 10       S011    U003         Pancakes  Breakfast 2024-12-06 08:00:00
# 11       S012    U004        Spaghetti     Dinner 2024-12-06 19:00:00
# ...

# %%
order_details_1 = order_details.drop_duplicates()

# %%
order_details_1
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2       1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 7       1008    U003 2024-12-04      Lunch    Veggie Burger     Canceled
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# ...

# %%
print("Missing Values in User Details:")
print(user_details_1.isnull().sum(), "\n")
# Out:
# Missing Values in User Details:
# User ID              0
# User Name            0
# Age                  0
# Location             0
# Registration Date    0
# Phone                0
# Email                0
# Favorite Meal        0
# Total Orders         0
# dtype: int64

# %%
print("Missing Values in Cooking Sessions:")
print(cooking_sessions_1.isnull().sum(), "\n")
# Out:
# Missing Values in Cooking Sessions:
# Session ID         0
# User ID            0
# Dish Name          0
# Meal Type          0
# Session Start      0
# Session End        0
# Duration (mins)    0
# Session Rating     0
# dtype: int64

# %%
print("Missing Values in Order Details:")
print(order_details_1.isnull().sum(), "\n")
# Out:
# Missing Values in Order Details:
# Order ID        0
# User ID         0
# Order Date      0
# Meal Type       0
# Dish Name       0
# Order Status    0
# Amount (USD)    0
# Time of Day     0
# Rating          2
# Session ID      0
# dtype: int64

# %%
user_details_2 = user_details_1.fillna('Unknown')  # Replace missing with 'Unknown' (customize this as needed)

# %%
user_details_2
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
# 5    U006    Frank Green   25         Austin        2023-06-15  888-777-6666
# 6    U007     Grace King   38         Boston        2023-07-02  999-888-7777
# 7    U008      Henry Lee   31          Miami        2023-08-11  101-202-3030
# 8    U009    Irene Moore   33         Dallas        2023-09-01  202-303-4040
# 9    U010     Jack White   29        Phoenix        2023-10-10  303-404-5050
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# ...

# %%
order_details_2 = order_details_1.dropna()

# %%
order_details_2
# Out:
#     Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0       1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1       1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 3       1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4       1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
# 5       1006    U002 2024-12-03     Dinner        Spaghetti    Completed
# 6       1007    U005 2024-12-04     Dinner  Grilled Chicken    Completed
# 8       1009    U001 2024-12-05     Dinner  Grilled Chicken    Completed
# 9       1010    U002 2024-12-05  Breakfast          Oatmeal    Completed
# 10      1011    U003 2024-12-06  Breakfast         Pancakes    Completed
# 11      1012    U004 2024-12-06     Dinner        Spaghetti    Completed
# 12      1013    U005 2024-12-07      Lunch     Caesar Salad    Completed
# 13      1014    U006 2024-12-07     Dinner  Grilled Chicken    Completed
# ...

# %%
merged_data_1 = pd.merge(user_details, cooking_sessions, on='User ID', how='inner')

# Merge the result with OrderDetails on 'User ID'
final_data = pd.merge(merged_data_1, order_details, on='User ID', how='inner')

# %%
final_data.head()
# Out:
#   User ID      User Name  Age  Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28  New York        2023-01-15  123-456-7890
# 1    U001  Alice Johnson   28  New York        2023-01-15  123-456-7890
# 2    U001  Alice Johnson   28  New York        2023-01-15  123-456-7890
# 3    U001  Alice Johnson   28  New York        2023-01-15  123-456-7890
# 4    U001  Alice Johnson   28  New York        2023-01-15  123-456-7890
#
#              Email Favorite Meal  Total Orders Session ID_x  ...  \
# 0  alice@email.com        Dinner            12         S001  ...
# 1  alice@email.com        Dinner            12         S001  ...
# 2  alice@email.com        Dinner            12         S001  ...
# 3  alice@email.com        Dinner            12         S004  ...
# 4  alice@email.com        Dinner            12         S004  ...
#
#   Session Rating Order ID Order Date Meal Type_y      Dish Name_y  \
# 0            4.5     1001 2024-12-01      Dinner        Spaghetti
# ...

# %%
# Find the most popular dishes
final_data.columns
# Out:
# Index(['User ID', 'User Name', 'Age', 'Location', 'Registration Date', 'Phone',
#        'Email', 'Favorite Meal', 'Total Orders', 'Session ID_x', 'Dish Name_x',
#        'Meal Type_x', 'Session Start', 'Session End', 'Duration (mins)',
#        'Session Rating', 'Order ID', 'Order Date', 'Meal Type_y',
#        'Dish Name_y', 'Order Status', 'Amount (USD)', 'Time of Day', 'Rating',
#        'Session ID_y'],
#       dtype='object')

# %%
popular_dishes = final_data['Dish Name_x'].value_counts()

# %%
popular_dishes
# Out:
# Dish Name_x
# Spaghetti          9
# Grilled Chicken    9
# Caesar Salad       7
# Pancakes           6
# Veggie Burger      4
# Oatmeal            3
# Name: count, dtype: int64

# %%
print("Top 10 Popular Dishes")
# Out:
# Top 10 Popular Dishes

# %%
print(popular_dishes.head(10))
# Out:
# Dish Name_x
# Spaghetti          9
# Grilled Chicken    9
# Caesar Salad       7
# Pancakes           6
# Veggie Burger      4
# Oatmeal            3
# Name: count, dtype: int64

# %%
age_analysis = final_data.groupby('Age')['Order ID'].count()

# %%
age_analysis
# Out:
# Age
# 25    1
# 27    4
# 28    9
# 30    4
# 31    1
# 35    9
# 38    1
# 42    9
# Name: Order ID, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
popular_dishes.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Popular Dishes')
plt.xlabel('Dish Name')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('popular_dishes.png')  # Save the chart
plt.show()

# %%
# Bar chart for age analysis
plt.figure(figsize=(10, 6))
age_analysis.plot(kind='bar', color='lightgreen')
plt.title('Orders by Age')
plt.xlabel('Age')
plt.ylabel('Number of Orders')
plt.tight_layout()
plt.savefig('orders_by_age.png')  # Save the chart
plt.show()

# %%
import seaborn as sns

# %%
merged_data = pd.merge(user_details, cooking_sessions, on='User ID', how='inner')

# Select relevant columns
numeric_data = merged_data[["Age", "Total Orders", "Duration (mins)", "Session Rating"]]

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
